# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.id.plot(kind='bar')
test.id.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-792b5d1ec62d> in <module>()
# ----> 1 train.id.plot(kind='bar')
#       2 test.id.plot(kind='bar')
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
#    3599                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3600                            **kwds)
#    3601     __call__.__doc__ = plot_series.__doc__
#    3602
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2672                  yerr=yerr, xerr=xerr,
#    2673                  label=label, secondary_y=secondary_y,
# -> 2674                  **kwds)
#    2675
#    2676
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1048         for ax in self.axes:
#    1049             self._post_plot_logic_common(ax, self.data)
# -> 1050             self._post_plot_logic(ax, self.data)
#    1051
#    1052     def _args_adjust(self):
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _post_plot_logic(self, ax, data)
#    2010         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    2011
# -> 2012         self._decorate_ticks(ax, name, str_index, s_edge, e_edge)
#    2013
#    2014     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge)
#    2014     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#    2015         ax.set_xlim((start_edge, end_edge))
# -> 2016         ax.set_xticks(self.tick_pos)
#    2017         ax.set_xticklabels(ticklabels)
#    2018         if name is not None and self.use_index:
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_xticks(self, ticks, minor)
#    2848         ACCEPTS: sequence of floats
#    2849         """
# -> 2850         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2851         self.stale = True
#    2852         return ret
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in set_ticks(self, ticks, minor)
#    1604         else:
#    1605             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1606             return self.get_major_ticks(len(ticks))
#    1607
#    1608     def _update_label_position(self, bboxes, bboxes2):
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1292             # update the new tick label properties from the old
#    1293             for i in range(numticks - len(self.majorTicks)):
# -> 1294                 tick = self._get_tick(major=True)
#    1295                 self.majorTicks.append(tick)
#    1296
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1673         else:
#    1674             tick_kw = self._minor_tick_kw
# -> 1675         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1676
#    1677     def _get_label(self):
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick2line(self)
#     412                           markersize=self._size,
#     413                           markeredgewidth=self._width,
# --> 414                           zorder=self._zorder)
#     415
#     416         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     365         # update kwargs before updating data to give the caller a
#     366         # chance to init axes (and hence unit support)
# --> 367         self.update(kwargs)
#     368         self.pickradius = pickradius
#     369         self.ind_offset = 0
#
# /Users/dwipam/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     849
#     850         for k, v in six.iteritems(props):
# --> 851             if k in ['axes']:
#     852                 setattr(self, k, v)
#     853             else:
#
# KeyboardInterrupt:
